# %% [markdown]
# # Proyecto 'Football Picks Analytics'
#
# ## Limpieza y consolidación de datos

# %% [markdown]
# ### Instalación y carga de paquetes

# %%
# %pip install pandas
# Out:
# Requirement already satisfied: pandas in /home/fer_barrera/Football-picks-analytics/.venv/lib/python3.12/site-packages (2.3.3)
# Requirement already satisfied: numpy>=1.26.0 in /home/fer_barrera/Football-picks-analytics/.venv/lib/python3.12/site-packages (from pandas) (2.3.4)
# Requirement already satisfied: python-dateutil>=2.8.2 in /home/fer_barrera/Football-picks-analytics/.venv/lib/python3.12/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /home/fer_barrera/Football-picks-analytics/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /home/fer_barrera/Football-picks-analytics/.venv/lib/python3.12/site-packages (from pandas) (2025.2)
# Requirement already satisfied: six>=1.5 in /home/fer_barrera/Football-picks-analytics/.venv/lib/python3.12/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 25.2 -> 25.3
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
# Importar librerias
import pandas as pd
from pathlib import Path

# %% [markdown]
# ### Carga de datos

# %%
# Verificación y carga del archivo .csv
ruta_base = Path.cwd()
ruta_csv = ruta_base.parent.parent.parent.parent / 'data' / 'Phase 2' / 'raw' / '2024_puntuacion.csv'

print(f'Buscando archivo en: {ruta_csv}')

if ruta_csv.exists():
    df = pd.read_csv(ruta_csv)
    print("Archivo cargado existosamente.")
else:
    print("El archivo NO existe en la ruta especificada.")
# Out:
# Buscando archivo en: /home/fer_barrera/Football-picks-analytics/data/Phase 2/raw/2024_puntuacion.csv
# Archivo cargado existosamente.

# %% [markdown]
# ### Verificación del contenido

# %%
# Analisis inicial del dataframe. Verificamos la estructura de los datos.
print(df.head())
# Out:
#        Fecha  Partido              Formato                Tipo         Etapa  \
# 0   5/3/2024        1               Vuelta                Club       Octavos
# 1   6/3/2024        2               Vuelta                Club       Octavos
# 2   6/3/2024        3  Eliminación Directa  Selección Nacional   Semifinales
# 3  10/3/2024        4             Matchday                Club  Fase regular
# 4  31/3/2024        5             Matchday                Club  Fase regular
#
#              Torneo             Local         Visitante Resultado  \
# 0  Champions League    Bayern München             Lazio     Local
# 1  Champions League       Real Madrid         RB Lepzig     Local
# 2  Copa Oro Femenil  Brasil (Femenil)  México (Femenil)     Local
# 3    Premier League         Liverpool   Manchester City    Empate
# 4    Premier League   Manchester City           Arsenal    Empate
#
#   Condición primera Condición segunda Estado Barrera Estado Chochos  \
# 0            Avanza     Indeterminada     Contestado     Contestado
# 1            Avanza     Indeterminada     Contestado     Contestado
# 2            Avanza     Indeterminada     Contestado     Contestado
# 3     Indeterminada     Indeterminada     Contestado     Contestado
# 4     Indeterminada     Indeterminada     Contestado     Contestado
#
#      Estado Dani   Estado Vélez  Puntos Barrera  Puntos Chochos  Puntos Dani  \
# 0     Contestado     Contestado               1               0            0
# 1     Contestado     Contestado               1               0            1
# 2     Contestado     Contestado               1               0            1
# 3  No contestado  No contestado               1               1            0
# 4     Contestado     Contestado               1               0            1
#
#    Puntos Vélez
# 0             0
# 1             1
# 2             0
# 3             0
# 4             1

# %%
# Verificamos la información del dataframe.
# Búsqueda de valores nulos y comprensión del tipo de datos.
print(df.info())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1189 entries, 0 to 1188
# Data columns (total 19 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Fecha              1189 non-null   object
#  1   Partido            1189 non-null   int64
#  2   Formato            1189 non-null   object
#  3   Tipo               1189 non-null   object
#  4   Etapa              1189 non-null   object
#  5   Torneo             1189 non-null   object
#  6   Local              1189 non-null   object
#  7   Visitante          1189 non-null   object
#  8   Resultado          1189 non-null   object
#  9   Condición primera  1189 non-null   object
#  10  Condición segunda  1189 non-null   object
#  11  Estado Barrera     1189 non-null   object
#  12  Estado Chochos     1189 non-null   object
#  13  Estado Dani        1189 non-null   object
#  14  Estado Vélez       1189 non-null   object
#  15  Puntos Barrera     1189 non-null   int64
#  16  Puntos Chochos     1189 non-null   int64
#  17  Puntos Dani        1189 non-null   int64
#  18  Puntos Vélez       1189 non-null   int64
# dtypes: int64(5), object(14)
# memory usage: 176.6+ KB
# None

# %% [markdown]
# ### Consolidación del contenido

# %%
# Eliminación de columnas innecesarias

# Creación de una copia del daraframe original para preservar los datso originales.
df_cleaned = df.copy()

# Eliminación
columnas_a_eliminar = ['Partido', 'Condición primera', 'Condición segunda']
df_cleaned = df.drop(columns = columnas_a_eliminar)

# Verificación
#print(df_cleaned.columns.tolist())
#print(df_cleaned.info())
# df_cleaned.head()

# %%
# Verificar valores únicos en columnas clave
print("=== VALORES ÚNICOS EN COLUMNAS CLAVE===\n")

columnas_clave = ['Formato', 'Tipo', 'Etapa', 'Torneo', 'Resultado', 
                'Estado Barrera', 'Estado Chochos', 'Estado Dani', 'Estado Vélez']

for columna in columnas_clave:
    print(f"{columna}:")
    print(f"Valores: {df_cleaned[columna].unique().tolist()}")
    print(f"Cantidad: {df_cleaned[columna].nunique()}")
    print()
# Out:
# === VALORES ÚNICOS EN COLUMNAS CLAVE===
#
# Formato:
# Valores: ['Vuelta', 'Eliminación Directa', 'Matchday', 'Ida', 'Amistoso']
# Cantidad: 5
#
# Tipo:
# Valores: ['Club', 'Selección Nacional']
# Cantidad: 2
#
# Etapa:
# Valores: ['Octavos', 'Semifinales', 'Fase regular', 'Final', 'Cuartos', 'Repesca', 'Preparación', 'Tercer Lugar', 'Dieciseisavos', 'Clasificación', 'Playoff']
# Cantidad: 11
#
# Torneo:
# Valores: ['Champions League', 'Copa Oro Femenil', 'Premier League', 'Copa del Rey', 'Europa League', 'Bundesliga', 'Liga MX', 'La Liga', 'Serie A', 'Champions Cup', 'Conference', 'Coppa Italia', 'RPL', 'FA Cup', 'AFC Champions League', 'CAF Champions League', 'Pokal', "The Custodian of the Two Holy Mosques' Cup", 'Sin torneo', 'Eurocopa', 'Copa América', 'OFC Nations Cup', 'Supercopa MX', 'Sudamericana', 'Liga Profesional de Argentina', 'Brasileirão Série A', 'Nile League', 'Leagues Cup', 'Liga 1', 'Categoría Primera A', 'UEFA Nations League', 'Eliminatorias Conmebol', 'Libertadores', 'SüperLig', 'Saudi Pro League', 'Intercontinental', 'Ligue 1', 'J League', 'Soúper Ligk Elladas', 'AFC Champions League Elite', 'Primera División de Chile', 'K League 1', 'Campeonato Uruguayo de Primera División', 'OFC WC Qualifiers', 'AFC Asian Qualifiers', 'CAN Qualifiers', 'Eredivisie', 'EFL Cup', 'Copa do Brasil', 'Liga Portugal', 'CONCACAF Nations League', 'MLS', 'Copa de la Liga Profesional', 'Copa Colombia', 'Scottish Cup', 'Trofeo de Campeones', 'Coupe de France', 'Scottish Premiership']
# Cantidad: 58
#
# Resultado:
# Valores: ['Local', 'Empate', 'Visitante']
# Cantidad: 3
#
# Estado Barrera:
# Valores: ['Contestado', 'No contestado']
# Cantidad: 2
#
# Estado Chochos:
# Valores: ['Contestado', 'No contestado']
# Cantidad: 2
#
# Estado Dani:
# Valores: ['Contestado', 'No contestado']
# Cantidad: 2
#
# Estado Vélez:
# Valores: ['Contestado', 'No contestado']
# Cantidad: 2

# %%
# Verificación del contenido de las puntuiaciones
print("===VERIFICACIÓN DE PUNTOS ===\n")

columnas_puntos = ['Puntos Barrera', 'Puntos Chochos', 'Puntos Dani', 'Puntos Vélez']

for columna in columnas_puntos:
    print(f"{columna}:")
    valores_unicos = df_cleaned[columna].value_counts().sort_index()
    for valor, cantidad in valores_unicos.items():
        print(f"{valor}: {cantidad} veces")
    print()
# Out:
# ===VERIFICACIÓN DE PUNTOS ===
#
# Puntos Barrera:
# 0: 600 veces
# 1: 589 veces
#
# Puntos Chochos:
# 0: 601 veces
# 1: 588 veces
#
# Puntos Dani:
# 0: 598 veces
# 1: 591 veces
#
# Puntos Vélez:
# 0: 683 veces
# 1: 506 veces

# %%
# Consolidación de datos de equipos locales

print("\nEQUIPOS ÚNICOS (LOCAL):")
equipos_local = df_cleaned['Local'].unique()
equipos_local.sort()
for i, equipo in enumerate(equipos_local[320:328]):
    print(f"  {i+1}. {equipo}")

print(f"\nTotal de equipos distintos (local): {len(equipos_local)}")
# Out:
# EQUIPOS ÚNICOS (LOCAL):
#   1. AEK
#   2. APOEL
#   3. AZ
#   4. Ajax
#   5. Al Ahli
#   6. Al Ahly
#   7. Al Ain
#   8. Al Hilal
#   9. Al Ittihad
#   10. Al Masry
#   11. Al Nassr
#   12. Al Sadd
#   13. Albania
#   14. Alemania
#   15. Always Ready
#   16. América
#   17. América de Cali
#   18. Anderlecht
#   19. Angola
#   20. Arabia Saudí
#   21. Argentina
#   22. Argentinos Juniors
#   23. Arsenal
#   24. Astana
#   25. Aston Villa
#   26. Atalanta
#   27. Athletic Club
#   28. Athletico Paranaense
#   29. Atlanta United
#   30. Atlas
#   31. Atlético Goianiense
#   32. Atlético Mineiro
#   33. Atlético Nacional
#   34. Atlético San Luis
#   35. Atlético Tucumán
#   36. Atlético de Madrid
#   37. Augsburg
#   38. Australia
#   39. Austria
#   40. Bahia
#   41. Banfield
#   42. Barcelona
#   43. Barcelona de Guayaquil
#   44. Barracas Central
#   45. Baréin
#   46. Bayer Leverkusen
#   47. Bayern München
#   48. Benfica
#   49. Beşiktaş
#   50. Boca Juniors
#   51. Bochum
#   52. Bodø/Glimt
#   53. Bolivia
#   54. Bologna
#   55. Borussia Dortmund
#   56. Borussia Mönchengladbach
#   57. Bosnia y Herzegovina
#   58. Botafogo
#   59. Bournemouth
#   60. Braga
#   61. Brasil
#   62. Brasil (Femenil)
#   63. Brentford
#   64. Brighton and Hove Albion
#   65. Bélgica
#   66. Cagliari
#   67. Canadá
#   68. Catar
#   69. Celta de Vigo
#   70. Celtic
#   71. Central Coast Mariners
#   72. Central Córdoba
#   73. Cerro Porteño
#   74. Charlotte
#   75. Chelsea
#   76. Chile
#   77. China
#   78. Cincinnati
#   79. Clube Brugge
#   80. Colo-Colo
#   81. Colombia
#   82. Columbus Crew
#   83. Congo
#   84. Corea del Norte
#   85. Corea del Sur
#   86. Corinthians
#   87. Costa Rica
#   88. Criciuma
#   89. Croacia
#   90. Cruz Azul
#   91. Cruzeiro
#   92. Crystal Palace
#   93. Cuiabá
#   94. Dallas
#   95. Dinamarca
#   96. Dinamo Zagreb
#   97. Ecuador
#   98. Eintracht Frankfurt
#   99. El Salvador
#   100. Emiratos Árabes Unidos
#   101. Empoli
#   102. Escocia
#   103. Eslovaquia
#   104. Eslovenia
#   105. España
#   106. Estados Unidos
#   107. Estrella Roja
#   108. Estudiantes
#   109. Etiopía
#   110. Everton
#   111. Fenerbahçe
#   112. Ferencváros
#   113. Feyenoord
#   114. Fiji
#   115. Finlandia
#   116. Fiorentina
#   117. Flamengo
#   118. Fluminense
#   119. Fortaleza
#   120. Francia
#   121. Freiburg
#   122. Fulham
#   123. Gabón
#   124. Galatasaray
#   125. Gales
#   126. Gamba Osaka
#   127. Genoa
#   128. Georgia
#   129. Gimnasia y Esgrima
#   130. Girona
#   131. Godoy Cruz
#   132. Grecia
#   133. Grêmio
#   134. Guadalajara
#   135. Guinea
#   136. Guinea-Bisáu
#   137. Gwangju
#   138. Hearts
#   139. Heidenheim
#   140. Hoffenheim
#   141. Honduras
#   142. Houston Dynamo
#   143. Hungría
#   144. Huracán
#   145. Independiente
#   146. Independiente de Medellín
#   147. Independiente del Valle
#   148. Indonesia
#   149. Inglaterra
#   150. Internacional
#   151. Internazionale
#   152. Ipswich Town
#   153. Irak
#   154. Irlanda
#   155. Irán
#   156. Islandia
#   157. Islas Salomón
#   158. Israel
#   159. Italia
#   160. Jamaica
#   161. Japón
#   162. Jordania
#   163. Juventus
#   164. Juárez
#   165. Kaiserslautern
#   166. Kawasaki Frontale
#   167. Kirguistán
#   168. Krasnodar
#   169. Kuwait
#   170. Kyoto Sanga
#   171. Köln
#   172. København
#   173. LA Galaxy
#   174. LAFC
#   175. Lanús
#   176. Las Palmas
#   177. Lazio
#   178. Lecce
#   179. Legia
#   180. Leicester City
#   181. Lens
#   182. León
#   183. Libertad
#   184. Liga de Quito
#   185. Lille
#   186. Liverpool
#   187. Ludogorets
#   188. Machida Zelvia
#   189. Mainz 05
#   190. Mallorca
#   191. Malmö
#   192. Malí
#   193. Manchester City
#   194. Manchester United
#   195. Mazatlán
#   196. Melgar
#   197. Midtjylland
#   198. Milan
#   199. Minnesota United
#   200. Moldavia
#   201. Montenegro
#   202. Monterrey
#   203. México
#   204. Mónaco
#   205. Nacional
#   206. Napoli
#   207. Nashville
#   208. Necaxa
#   209. New England Revolution
#   210. New York City
#   211. New York RB
#   212. Newcastle United
#   213. Newell's Old Boys
#   214. Nice
#   215. Noruega
#   216. Nottingham Forest
#   217. Nueva Zelanda
#   218. Olympiacos
#   219. Olympique Lyonnais
#   220. Olympique de Marseille
#   221. Omán
#   222. Once Caldas
#   223. Orlando City
#   224. PAOK
#   225. PSG
#   226. PSV
#   227. Pachuca
#   228. Palestina
#   229. Palestino
#   230. Palmeiras
#   231. Panamá
#   232. Panathinaikos
#   233. Papúa Nueva Guínea
#   234. Paraguay
#   235. Países Bajos
#   236. Perú
#   237. Peñarol
#   238. Philadelphia Union
#   239. Pohang Steelers
#   240. Polonia
#   241. Portland Timbers
#   242. Porto
#   243. Portugal
#   244. Puebla
#   245. Querétaro
#   246. RB Bragantino
#   247. RB Lepzig
#   248. RB Salzburg
#   249. Racing
#   250. Racing de Montevideo
#   251. Rangers
#   252. Rayo Vallecano
#   253. Real Betis
#   254. Real Madrid
#   255. Real Salt Lake
#   256. Real Sociedad
#   257. Reims
#   258. República Checa
#   259. River Plate
#   260. Roma
#   261. Rosario Central
#   262. Rumania
#   263. SCP
#   264. Samoa
#   265. San Jose Earthquakes
#   266. San Lorenzo
#   267. Sanfrecce Hiroshima
#   268. Santos Laguna
#   269. Seattle Sounders
#   270. Serbia
#   271. Sevilla
#   272. Shakhtar Donetsk
#   273. Shanghai Port
#   274. Shanghai Shenhua
#   275. Sheffield United
#   276. Slavia Praha
#   277. Slovan
#   278. Slovan Bratislava
#   279. Southampton
#   280. Sparta Praha
#   281. Sporting Kansas City
#   282. St. Louis City
#   283. St. Pauli
#   284. Stade Brestois 29
#   285. Sturm Graz
#   286. Stuttgart
#   287. Sudáfrica
#   288. Suecia
#   289. Suiza
#   290. Surinam
#   291. São Paulo
#   292. Tahití
#   293. Talleres
#   294. Tigres
#   295. Tijuana
#   296. Togo
#   297. Toluca
#   298. Torino
#   299. Tottenham Hotspur
#   300. Turquía
#   301. Twente
#   302. Ucrania
#   303. Udinese
#   304. Ulsan
#   305. Union Berlin
#   306. Union Saint-Gilloise
#   307. Universidad Católica (Ecuador)
#   308. Universidad Nacional
#   309. Universitario
#   310. Unión
#   311. Uruguay
#   312. Uzbekistán
#   313. Valencia
#   314. Vancouver Whitecaps
#   315. Vanuatu
#   316. Venezuela
#   317. Viktoria Plzeň
#   318. Villarreal
#   319. Vissel Kobe
#   320. Vélez
#   321. Werder Bremen
#   322. West Ham United
#   323. Wolfsburg
#   324. Wolverhampton Wanderers
#   325. Yokohama F. Marinos
#   326. Young Boys
#   327. Zenit
#
# Total de equipos distintos (local): 327

# %%
# Consolidación de datos de equipos visitantes

print("\nEQUIPOS ÚNICOS (VISITANTE):")
equipos_visitante = df_cleaned['Visitante'].unique()

equipos_visitante.sort()
for i, equipo in enumerate(equipos_visitante):
    print(f" {i+1}.{equipo}")

print(f"\nTotal de equipos distintos (visitante): {len(equipos_visitante)}")
# Out:
# EQUIPOS ÚNICOS (VISITANTE):
#  1.AZ
#  2.Ajax
#  3.Al Ahli
#  4.Al Ahly
#  5.Al Ain
#  6.Al Hilal
#  7.Al Ittihad
#  8.Al Nassr
#  9.Al Sadd
#  10.Albania
#  11.Alemania
#  12.Alianza Lima
#  13.Almería
#  14.Always Ready
#  15.América
#  16.América de Cali
#  17.Anderlecht
#  18.Andorra
#  19.Arabia Saudí
#  20.Argelia
#  21.Argentina
#  22.Arsenal
#  23.Aston Villa
#  24.Atalanta
#  25.Athletic Club
#  26.Athletico Paranaense
#  27.Atlas
#  28.Atlético Goianiense
#  29.Atlético Mineiro
#  30.Atlético Nacional
#  31.Atlético San Luis
#  32.Atlético de Madrid
#  33.Auckland City
#  34.Augsburg
#  35.Austin
#  36.Australia
#  37.Austria
#  38.Azerbaiyán
#  39.Bahia
#  40.Banfield
#  41.Barcelona
#  42.Barcelona de Guayaquil
#  43.Baréin
#  44.Bayer Leverkusen
#  45.Bayern München
#  46.Başakşehir
#  47.Belgrano
#  48.Benfica
#  49.Beşiktaş
#  50.Boca Juniors
#  51.Bochum
#  52.Bodø/Glimt
#  53.Bolivia
#  54.Bologna
#  55.Borussia Dortmund
#  56.Borussia Mönchengladbach
#  57.Bosnia y Herzegovina
#  58.Botafogo
#  59.Bournemouth
#  60.Braga
#  61.Brasil
#  62.Brentford
#  63.Brighton and Hove Albion
#  64.Bulgaria
#  65.Bélgica
#  66.Canadá
#  67.Catar
#  68.Celta de Vigo
#  69.Celtic
#  70.Central Córdoba
#  71.Cerro Porteño
#  72.Charlotte
#  73.Chelsea
#  74.Chicago Fire
#  75.Chile
#  76.China
#  77.Clube Brugge
#  78.Colo-Colo
#  79.Colombia
#  80.Colorado Rapids
#  81.Columbus Crew
#  82.Congo
#  83.Corea del Sur
#  84.Corinthians
#  85.Costa Rica
#  86.Criciuma
#  87.Croacia
#  88.Cruz Azul
#  89.Cruzeiro
#  90.Crystal Palace
#  91.Cuiabá
#  92.Cádiz
#  93.DC United
#  94.Dallas
#  95.Darmstadt
#  96.Deportes Tolima
#  97.Dinamarca
#  98.Dinamo Zagreb
#  99.Dinamo de Moscú
#  100.Dynamo Kiev
#  101.Ecuador
#  102.Eintracht Frankfurt
#  103.Elfsborg
#  104.Emiratos Árabes Unidos
#  105.Escocia
#  106.Eslovaquia
#  107.Eslovenia
#  108.Espanyol
#  109.España
#  110.Esperance de Tunis
#  111.Estados Unidos
#  112.Estrella Roja
#  113.Estudiantes
#  114.Etiopía
#  115.Everton
#  116.Fenerbahçe
#  117.Ferencvaros
#  118.Feyenoord
#  119.Fiji
#  120.Finlandia
#  121.Fiorentina
#  122.Flamengo
#  123.Fluminense
#  124.Fortaleza
#  125.Francia
#  126.Freiburg
#  127.Fulham
#  128.Galatasaray
#  129.Gales
#  130.Gent
#  131.Georgia
#  132.Getafe
#  133.Ghana
#  134.Gimcheon Sangmu
#  135.Gimnasia y Esgrima
#  136.Girona
#  137.Granada
#  138.Grecia
#  139.Grêmio
#  140.Guadalajara
#  141.Guatemala
#  142.Guinea
#  143.Guinea-Bisáu
#  144.Gwangju
#  145.Hearts
#  146.Hertha Berlin
#  147.Hibernian
#  148.Hoffenheim
#  149.Honduras
#  150.Huachipato
#  151.Hungría
#  152.Huracán
#  153.Independiente
#  154.Independiente de Medellín
#  155.Independiente del Valle
#  156.Inglaterra
#  157.Inter Miami
#  158.Internacional
#  159.Internazionale
#  160.Ipswich Town
#  161.Irak
#  162.Irlanda
#  163.Irlanda del Norte
#  164.Irán
#  165.Islandia
#  166.Islas Salomón
#  167.Israel
#  168.Italia
#  169.Jamaica
#  170.Japón
#  171.Jordania
#  172.Junior
#  173.Juventus
#  174.Juárez
#  175.Kawasaki Frontale
#  176.Kazajistán
#  177.København
#  178.LA Galaxy
#  179.Lanús
#  180.Lazio
#  181.Leicester City
#  182.Lens
#  183.León
#  184.Libertad
#  185.Liechtenstein
#  186.Liga de Quito
#  187.Lille
#  188.Liverpool
#  189.Ludogorets
#  190.Luxemburgo
#  191.Macedonia del Norte
#  192.Machida Zelvia
#  193.Mainz 05
#  194.Mallorca
#  195.Malta
#  196.Malí
#  197.Manchester City
#  198.Manchester United
#  199.Marruecos
#  200.Mazatlán
#  201.Midtjylland
#  202.Milan
#  203.Minnesota United
#  204.Montenegro
#  205.Monterrey
#  206.Montréal
#  207.Monza
#  208.México
#  209.México (Femenil)
#  210.Mónaco
#  211.Napoli
#  212.Necaxa
#  213.New York RB
#  214.Newcastle United
#  215.Newell's Old Boys
#  216.Nice
#  217.Noah
#  218.Noruega
#  219.Nottingham Forest
#  220.Nueva Caledonia
#  221.Nueva Zelanda
#  222.Olympiacos
#  223.Olympique Lyonnais
#  224.Olympique de Marseille
#  225.Omán
#  226.PAOK
#  227.PSG
#  228.PSV
#  229.Pachuca
#  230.Palestino
#  231.Palmeiras
#  232.Panamá
#  233.Panathinaikos
#  234.Paraguay
#  235.Países Bajos
#  236.Persépolis
#  237.Perú
#  238.Peñarol
#  239.Platense
#  240.Pohang Steelers
#  241.Polonia
#  242.Portland Timbers
#  243.Porto
#  244.Portugal
#  245.Puebla
#  246.Querétaro
#  247.RB Bragantino
#  248.RB Lepzig
#  249.RB Salzburg
#  250.Racing
#  251.Rangers
#  252.Real Betis
#  253.Real Madrid
#  254.Real Sociedad
#  255.República Checa
#  256.República Democrática del Congo
#  257.River Plate
#  258.Roma
#  259.Rosario Central
#  260.Rostov
#  261.Rumania
#  262.SCP
#  263.Samoa
#  264.San Jose Earthquakes
#  265.San Lorenzo
#  266.San Luis
#  267.Sanfrecce Hiroshima
#  268.Santos Laguna
#  269.Sarmiento
#  270.Sassuolo
#  271.Seattle Sounders
#  272.Serbia
#  273.Sevilla
#  274.Shakhtar
#  275.Shakhtar Donetsk
#  276.Shandong
#  277.Shandong Luneng
#  278.Shanghai Port
#  279.Shenhua
#  280.Shonan Bellmare
#  281.Slavia Praha
#  282.Slovan Bratislava
#  283.Southampton
#  284.Sparta Praha
#  285.St. Pauli
#  286.Stade Brestois 29
#  287.Sturm Graz
#  288.Stuttgart
#  289.Sudáfrica
#  290.Suecia
#  291.Suiza
#  292.Surinam
#  293.São Paulo
#  294.Tahití
#  295.Talleres
#  296.Tigre
#  297.Tigres
#  298.Tijuana
#  299.Toluca
#  300.Torino
#  301.Toronto
#  302.Tottenham Hotspur
#  303.Turquía
#  304.Twente
#  305.Ucrania
#  306.Udinese
#  307.Ulsan
#  308.Union Berlin
#  309.Universidad Católica
#  310.Universidad Católica (Ecuador)
#  311.Universidad Nacional
#  312.Universitario
#  313.Uruguay
#  314.Uzbekistán
#  315.Valencia
#  316.Vancouver Whitecaps
#  317.Vanuatu
#  318.Vasco da Gama
#  319.Venezuela
#  320.Villarreal
#  321.Vissel Kobe
#  322.Vitoria
#  323.Vélez
#  324.Werder Bremen
#  325.West Ham United
#  326.Wolfsburgo
#  327.Wolverhampton Wanderers
#  328.Yokohama F. Marinos
#  329.Young Boys
#
# Total de equipos distintos (visitante): 329

# %%
# Consolidación de datos de la columna Torneo

torneos = df_cleaned['Torneo'].unique()

torneos.sort()
for i, torneo in enumerate(torneos):
    print(f"{i+1}.{torneo}")

print(f"Torneos totales: {len(torneos)}")
# Out:
# 1.AFC Asian Qualifiers
# 2.AFC Champions League
# 3.AFC Champions League Elite
# 4.Brasileirão Série A
# 5.Bundesliga
# 6.CAF Champions League
# 7.CAN Qualifiers
# 8.CONCACAF Nations League
# 9.Campeonato Uruguayo de Primera División
# 10.Categoría Primera A
# 11.Champions Cup
# 12.Champions League
# 13.Conference
# 14.Copa América
# 15.Copa Colombia
# 16.Copa Oro Femenil
# 17.Copa de la Liga Profesional
# 18.Copa del Rey
# 19.Copa do Brasil
# 20.Coppa Italia
# 21.Coupe de France
# 22.EFL Cup
# 23.Eliminatorias Conmebol
# 24.Eredivisie
# 25.Eurocopa
# 26.Europa League
# 27.FA Cup
# 28.Intercontinental
# 29.J League
# 30.K League 1
# 31.La Liga
# 32.Leagues Cup
# 33.Libertadores
# 34.Liga 1
# 35.Liga MX
# 36.Liga Portugal
# 37.Liga Profesional de Argentina
# 38.Ligue 1
# 39.MLS
# 40.Nile League
# 41.OFC Nations Cup
# 42.OFC WC Qualifiers
# 43.Pokal
# 44.Premier League
# 45.Primera División de Chile
# 46.RPL
# 47.Saudi Pro League
# 48.Scottish Cup
# 49.Scottish Premiership
# 50.Serie A
# 51.Sin torneo
# 52.Soúper Ligk Elladas
# 53.Sudamericana
# 54.Supercopa MX
# 55.SüperLig
# 56.The Custodian of the Two Holy Mosques' Cup
# 57.Trofeo de Campeones
# 58.UEFA Nations League
# Total de torneos: 58

# %%
# Estandarización de nombres de equipos

correcciones_de_equipos = {
    'Esperance de Tunis': 'Espérance de Tunis',
    'Ferencvaros': 'Ferenváros', 
    'Shanghai': 'Shanghai Shenhua',
    'Shandong': 'Shandong Luneng',
    'Shakhtar': 'Shakhtar Donetsk',
    'San Luis': 'Atlético San Luis',
    'Wolfsburgo': 'Wolfsburg',
    'Slovan': 'Slovan Bratislava'
}

print("=== APLICANDO CORRECCIONES ===\n")

# Correción de la columna 'Local'
correcciones_aplicadas_local = 0

for nombre_incorrecto, nombre_correcto in correcciones_de_equipos.items():
    if nombre_incorrecto in df_cleaned['Local'].values:
        mascara = df_cleaned['Local'] == nombre_incorrecto
        df_cleaned.loc[mascara, 'Local'] = nombre_correcto
        correcciones_aplicadas_local += mascara.sum()
        print(f"Local: '{nombre_incorrecto}' -> '{nombre_correcto}' ({mascara.sum()}) correcciones")

# Correción de la columna 'Local'
correcciones_aplicadas_visitante = 0

for nombre_incorrecto, nombre_correcto in correcciones_de_equipos.items():
    if nombre_incorrecto in df_cleaned['Visitante'].values:
        mascara = df_cleaned['Visitante'] == nombre_incorrecto
        df_cleaned.loc[mascara, 'Visitante'] = nombre_correcto
        correcciones_aplicadas_visitante += mascara.sum()
        print(f"Visitante: '{nombre_incorrecto}' -> '{nombre_correcto}' ({mascara.sum()}) correcciones")

print(f"\nTotal correcciones aplicadas:")
print(f"  - Local: {correcciones_aplicadas_local}")
print(f"  - Visitante: {correcciones_aplicadas_visitante}")
# Out:
# === APLICANDO CORRECCIONES ===
#
#
# Total correcciones aplicadas:
#   - Local: 0
#   - Visitante: 0

# %%
# Verificación sobre la aplicación de correcciones

print("\n=== VERIFICACIÓN POST-CORRECCIÓN ===\n")

nombres_que_ya_no_deberian_existir = ['Esperance de Tunis', 'Ferencvaros', 'Shanghai', 'Shandong', 'Shakhtar', 'San Luis', 'Wolfsburgo', 'Slovan']

print("Nombres que NO deberían existir (verificación):")
for nombre in nombres_que_ya_no_deberian_existir:
    existe_local = nombre in df_cleaned['Local'].values
    existe_visitante = nombre in df_cleaned['Visitante'].values
    print(f"'{nombre}': Local={existe_local}, Vistante:={existe_visitante}")
# Out:
# === VERIFICACIÓN POST-CORRECCIÓN ===
#
# Nombres que NO deberían existir (verificación):
# 'Esperance de Tunis': Local=False, Vistante:=False
# 'Ferencvaros': Local=False, Vistante:=False
# 'Shanghai': Local=False, Vistante:=False
# 'Shandong': Local=False, Vistante:=False
# 'Shakhtar': Local=False, Vistante:=False
# 'San Luis': Local=False, Vistante:=False
# 'Wolfsburgo': Local=False, Vistante:=False
# 'Slovan': Local=False, Vistante:=False

# %%
# Quitar espacios en blanco

# Guardar este dataframe para trabajar con él

# %% [markdown]
# ### Apunte Métodos
#
# Riesgo -> Es necesario la información previa
#
# Matriz de doble entrada
#
# Vertical: Alternativas (A)
# Horizontal: Estado de la naturaleza (E)
#
# Calculo de la matriz: (A*Cantidad) - (E*Costo)
#
# Frecuencia relativa = Probabilidades
#
# Cada resultado * Probabilidad = Matriz de valor esperado
#
# Resultado = Suma (Búsqueda del mejor estado)
#
#  ** Evaluar riesgo de inversiones**
#
#  Tarea #8. Desarrollar un ejemplo de toma de  decisiones en condiciones de riesgo
# En Power Point
